# %%
from Diagnose import Diagnose as DG
import NutritionCalculator as NC
import Nutrientscore as NS

# %%
#################사용자 정보 입력#################
age=60
gender='Female'
height=165/100
weight=51
state='CKD' # NA (일반인), CKD (만성신부전), HD (혈액투석), PD (복막투석)
PDk=0 # 복막투석 시 투석액 칼로리
eGFR=50 # 사구체 여과율
uACR = 50 
protein_loss=0
albumin=3.4 # 혈중 알부민
FBG=90
OGTT=135
HbA1c=7.1
TG=600
LDL=105
SBP=130
DBP=80
CK=6
CP=5
CCa=4
mealtype = "식단" # 식단 메인반찬 단품요리 / 간식 간식콤보 음료
foodtype='음식' #가공식품 음식

##################################################
top_n=10

dig = DG(gender, height, weight, state, PDk, eGFR, uACR, protein_loss, albumin, FBG, OGTT, HbA1c, TG, LDL, SBP, DBP, CK, CP, CCa)
Ncalc = NC.NutritionCalculator(gender, height, weight, state, PDk, eGFR, uACR, protein_loss, albumin, FBG, OGTT, HbA1c, TG, LDL, SBP, DBP, CK, CP, CCa)
FS = NS.FoodScorer(gender, height, weight, state, PDk, eGFR, uACR, protein_loss, albumin, FBG, OGTT, HbA1c, TG, LDL, SBP, DBP, CK, CP, CCa, mealtype, foodtype, top_n)

# %%
sw_r, bmi_r, albumin_r, kidney_r, diabetes_r, blood_pressure_r, triglycerides_r, cholesterol_r, K_r, P_r, Ca_r = dig.diagnose()

print(f'BMI = {bmi_r}')
print(f'Albumin level = {albumin_r} ({albumin} g/dL)')
print(f"Kidney level = {kidney_r}")
print(f'Diabetes = {diabetes_r}')
print(f'Blood pressure level = {blood_pressure_r} ({SBP} mmHg/{DBP} mmHg)')
print(f'Triglyceride level = {triglycerides_r} ({TG} mg/dL)')
print(f'LDL level = {cholesterol_r} ({LDL} mg/dL)')
print(f'Potassium level = {K_r} ({CK} mEq/L)')
print(f'Phosphorus level = {P_r} ({CP} mg/dL)')
print(f'Calcium level = {Ca_r} ({CCa} mg/dL)')
# Out:
# BMI = 18.73278236914601
# Albumin level = 저알부민혈증 (3.4 g/dL)
# Kidney level = G3a, 높은 위험
# Diabetes = 당뇨병
# Blood pressure level = 고혈압 전단계 1기 (130 mmHg/80 mmHg)
# Triglyceride level = 높음 (600 mg/dL)
# LDL level = 높음 (105 mg/dL)
# Potassium level = 높음 (6 mEq/L)
# Phosphorus level = 높음 (5 mg/dL)
# Calcium level = 낮음 (4 mg/dL)

# %%
Ncalc.print_nutrient_criteria()
# Out:
# (                 최소 권장 섭취량  최대 권장 섭취량
#  영양소
#  Carbohydrate (g)    192.96     257.28
#  Protein (g)          45.74      45.74
#  Fat (g)              28.59      28.59
#  Na (mg)                  -    2000.00
#  K (mg)                   -    2000.00
#  P (mg)                   -     686.07
#  Sugar (g)                -      42.88,
#  1715.17,
#  ['당', '콜레스테롤', '나트륨', '칼륨', '인'])

# %%
top_diet=FS.top_diets()
FS.diet_ranking(top_diet)
# Out:
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:65: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if total_nutrition[1]<CHOA:
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:66: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CHOS = max(1-((total_nutrition[1]-CHOA)/CHOA)**2, -1) *5
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if total_nutrition[2]<ProA:
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:74: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif total_nutrition[2]>ProB:
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:75: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ProS = max(1-((total_nutrition[2]-ProB)/ProA)**2, -1) *5
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:79: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if total_nutrition[3]<FatA:
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:81: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif total_nutrition[3]>FatB:
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:82: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   FatS = max(1-((total_nutrition[3]-FatB)/FatA)**2, -1) *5
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:86: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   NaS = max(-total_nutrition[4]*Naw/Na, -2) *5
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:87: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   SugarS = max(-total_nutrition[5]*Sugarw/Sugar, -2) *5
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:88: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   KS = max(-total_nutrition[6]*Kw/K,-2) *5
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:89: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   PS = max(-total_nutrition[7]*Pw/P, -2) *5
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:67: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif total_nutrition[1]>CHOB:
# d:\GitHub\Food_recommendation\Kidney_food_recommender\Nutrientscore.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CHOS = max(1-((total_nutrition[1]-CHOB)/CHOA)**2, -1) *5
#                                                 식단 구성  식단 점수         칼로리  \
# 순위
# 1   기장밥 100.0g & 새우구이 90.0g & 단무지 15.0g & 나박김치 65....  49.77  534.64kcal
# 2   기장밥 100.0g & 새우구이 90.0g & 깻잎찜 50.0g & 나박김치 64....  49.75  534.67kcal
# 3   기장밥 100.0g & 새우구이 90.0g & 오징어젓_양념 5.0g & 나박김치 ...  49.69  536.52kcal
# 4   기장밥 100.0g & 새우구이 90.0g & 오이장아찌 25.0g & 나박김치 6...  49.69  534.83kcal
# 5   기장밥 100.0g & 새우구이 90.0g & 저염오이피클 50.0g & 나박김치 ...  49.67  534.12kcal
# 6   기장밥 100.0g & 새우구이 90.0g & 적채피클 50.0g & 나박김치 63...  49.62   536.0kcal
# 7   기장밥 100.0g & 새우구이 90.0g & 비트무피클 50.0g & 나박김치 6...  49.54  534.15kcal
# 8   기장밥 100.0g & 새우구이 90.0g & 새송이버섯피클 50.0g & 나박김치...  49.39  532.58kcal
# 9   기장밥 100.0g & 새우구이 90.0g & 레몬양파피클 50.0g & 나박김치 ...  49.28  533.79kcal
# 10  기장밥 100.0g & 새우구이 90.0g & 단무지 15.0g & 얼갈이배추김치 ...  49.27  536.63kcal
#
#              탄수화물          단백질             지방              나트륨  \
# 순위
# 1   52.72g (4.96)  54.34g (-5)  11.86g (4.27)  1236.25mg (-10)
# 2   52.73g (4.96)  54.51g (-5)  11.85g (4.27)  1153.73mg (-10)
# 3   52.72g (4.96)  54.81g (-5)  11.87g (4.26)  1261.01mg (-10)
# 4    52.7g (4.96)  54.35g (-5)   11.9g (4.25)  1338.44mg (-10)
# 5   52.74g (4.96)  54.38g (-5)  11.83g (4.28)  1153.91mg (-10)
# 6   52.57g (4.96)  54.69g (-5)  12.08g (4.17)  1154.65mg (-10)
# 7   52.74g (4.96)  54.33g (-5)  11.84g (4.28)  1156.88mg (-10)
# 8   52.73g (4.96)  54.61g (-5)  11.85g (4.27)  1154.22mg (-10)
# 9   52.75g (4.96)  54.31g (-5)  11.82g (4.29)  1153.94mg (-10)
# 10  52.49g (4.96)  54.37g (-5)  12.19g (4.11)  1146.04mg (-10)
#
#                 칼륨               인               당류
# 순위
# 1   0.64mg (-9.08)  726.62mg (-10)  424.18g (-0.37)
# 2   0.63mg (-9.11)  729.12mg (-10)  426.69g (-0.37)
# 3   0.69mg (-9.14)  731.05mg (-10)   428.82g (-0.4)
# 4   0.83mg (-9.04)  723.57mg (-10)   424.3g (-0.48)
# 5    0.8mg (-9.11)   728.4mg (-10)  423.36g (-0.46)
# 6   0.68mg (-9.11)  728.98mg (-10)   436.64g (-0.4)
# 7   0.91mg (-9.17)  733.44mg (-10)  423.51g (-0.53)
# 8   0.61mg (-9.49)  759.13mg (-10)   424.2g (-0.35)
# 9   1.48mg (-9.11)  728.46mg (-10)  422.92g (-0.86)
# 10  0.62mg (-9.44)  754.98mg (-10)  426.51g (-0.36)

# %%
FS.diet_ranking(top_diet).to_csv('result.csv',encoding='ANSI')
