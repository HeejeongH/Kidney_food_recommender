# %%
from Diagnose import Diagnose as DG
import NutritionCalculator as NC
import Nutrientscore as NS

# %%
#################사용자 정보 입력#################
age=60
gender='Female'
height=165/100
weight=51
state='CKD' # NA (일반인), CKD (만성신부전), HD (혈액투석), PD (복막투석)
PDk=0 # 복막투석 시 투석액 칼로리
eGFR=50 # 사구체 여과율
uACR = 50 
protein_loss=0
albumin=3.4 # 혈중 알부민
FBG=90
OGTT=135
HbA1c=7.1
TG=600
LDL=105
SBP=130
DBP=80
CK=6
CP=5
CCa=4
mealtype = "식단" # 식단 메인반찬 단품요리 / 간식 간식콤보 음료
foodtype='음식' #가공식품 음식

##################################################
top_n=10

dig = DG(gender, height, weight, state, PDk, eGFR, uACR, protein_loss, albumin, FBG, OGTT, HbA1c, TG, LDL, SBP, DBP, CK, CP, CCa)
Ncalc = NC.NutritionCalculator(gender, height, weight, state, PDk, eGFR, uACR, protein_loss, albumin, FBG, OGTT, HbA1c, TG, LDL, SBP, DBP, CK, CP, CCa)
FS = NS.FoodScorer(gender, height, weight, state, PDk, eGFR, uACR, protein_loss, albumin, FBG, OGTT, HbA1c, TG, LDL, SBP, DBP, CK, CP, CCa, mealtype, foodtype, top_n)

# %%
sw_r, bmi_r, albumin_r, kidney_r, diabetes_r, blood_pressure_r, triglycerides_r, cholesterol_r, K_r, P_r, Ca_r = dig.diagnose()

print(f'BMI = {bmi_r}')
print(f'Albumin level = {albumin_r} ({albumin} g/dL)')
print(f"Kidney level = {kidney_r}")
print(f'Diabetes = {diabetes_r}')
print(f'Blood pressure level = {blood_pressure_r} ({SBP} mmHg/{DBP} mmHg)')
print(f'Triglyceride level = {triglycerides_r} ({TG} mg/dL)')
print(f'LDL level = {cholesterol_r} ({LDL} mg/dL)')
print(f'Potassium level = {K_r} ({CK} mEq/L)')
print(f'Phosphorus level = {P_r} ({CP} mg/dL)')
print(f'Calcium level = {Ca_r} ({CCa} mg/dL)')
# Out:
# BMI = 18.73278236914601
# Albumin level = 저알부민혈증 (3.4 g/dL)
# Kidney level = G3a, 높은 위험
# Diabetes = 당뇨병
# Blood pressure level = 고혈압 전단계 1기 (130 mmHg/80 mmHg)
# Triglyceride level = 높음 (600 mg/dL)
# LDL level = 높음 (105 mg/dL)
# Potassium level = 높음 (6 mEq/L)
# Phosphorus level = 높음 (5 mg/dL)
# Calcium level = 낮음 (4 mg/dL)

# %%
Ncalc.print_nutrient_criteria()
# Out:
# (                 최소 권장 섭취량  최대 권장 섭취량
#  영양소
#  Carbohydrate (g)    192.96     257.28
#  Protein (g)          45.74      45.74
#  Fat (g)              28.59      28.59
#  Na (mg)                  -    2000.00
#  K (mg)                   -    2000.00
#  P (mg)                   -     686.07
#  Sugar (g)                -      42.88,
#  1715.17,
#  ['당', '콜레스테롤', '나트륨', '칼륨', '인'])

# %%
top_diet=FS.top_diets()
FS.diet_ranking(top_diet)
# Out:
#                                                 식단 구성  식단 점수        칼로리  \
# 순위
# 1   보리밥 200g & 라볶이 200g & 단무지 30g & 나박김치 100g & 토란...  53.10  667.9kcal
# 2   보리밥 200g & 라볶이 200g & 오이장아찌 50g & 나박김치 100g & ...  52.73  671.0kcal
# 3   보리밥 200g & 라볶이 200g & 오징어젓_양념 10g & 나박김치 100g ...  52.63  670.0kcal
# 4   보리밥 200g & 고등어조림 100g & 단무지 30g & 나박김치 100g & ...  52.03  540.9kcal
# 5   보리밥 200g & 라볶이 200g & 단무지 30g & 깍두기 50g & 토란국 ...  52.03  674.4kcal
# 6   보리밥 200g & 라볶이 200g & 미역초무침 50g & 나박김치 100g & ...  51.96  681.5kcal
# 7   보리밥 200g & 라볶이 200g & 김구이_조미김 5g & 나박김치 100g &...  51.93  687.5kcal
# 8   보리밥 200g & 라볶이 200g & 파래무침 30g & 나박김치 100g & 토...  51.89  678.7kcal
# 9   보리밥 200g & 라볶이 200g & 단무지 30g & 물김치_돌나물 400g &...  51.74  677.9kcal
# 10  보리밥 200g & 고등어조림 100g & 오이장아찌 50g & 나박김치 100g ...  51.74  544.0kcal
#
#               탄수화물            단백질             지방              나트륨  \
# 순위
# 1   126.13g (1.43)  16.02g (4.86)  10.82g (4.66)   1932.6mg (-10)
# 2   126.68g (1.34)   16.1g (4.85)   10.9g (4.63)   2137.0mg (-10)
# 3   125.75g (1.48)  16.93g (4.73)  10.83g (4.65)   1982.1mg (-10)
# 4    89.95g (4.76)  21.61g (3.35)  10.24g (4.81)   1700.6mg (-10)
# 5    127.1g (1.28)  16.34g (4.82)  10.97g (4.61)   1959.6mg (-10)
# 6   128.03g (1.14)  16.51g (4.79)  11.27g (4.51)   1993.0mg (-10)
# 7   126.86g (1.32)  16.94g (4.73)  12.27g (4.07)  1967.55mg (-10)
# 8    126.9g (1.31)  16.98g (4.72)  11.27g (4.51)   1987.8mg (-10)
# 9   127.98g (1.15)   16.8g (4.75)  10.76g (4.68)   2503.6mg (-10)
# 10    90.5g (4.74)  21.69g (3.31)  10.32g (4.79)   1905.0mg (-10)
#
#                칼륨                인               당류
# 순위
# 1    8.58mg (-10)  807.7mg (-7.85)    215.3g (-5.0)
# 2    8.96mg (-10)  802.0mg (-7.87)   216.0g (-5.22)
# 3    8.68mg (-10)  816.3mg (-8.17)   224.3g (-5.06)
# 4   10.09mg (-10)    941.7mg (-10)   293.3g (-5.88)
# 5    9.51mg (-10)  860.2mg (-8.14)   223.3g (-5.55)
# 6    9.09mg (-10)  878.0mg (-8.18)    224.5g (-5.3)
# 7    8.45mg (-10)  853.7mg (-8.26)  226.55g (-4.93)
# 8    8.96mg (-10)  945.7mg (-8.42)   231.2g (-5.22)
# 9    9.64mg (-10)  898.7mg (-8.21)   225.3g (-5.62)
# 10  10.47mg (-10)    936.0mg (-10)    294.0g (-6.1)

# %%
FS.diet_ranking(top_diet).to_csv('result.csv',encoding='ANSI')
